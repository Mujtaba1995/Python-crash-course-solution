# %%
#Dictionaries are key value pairs
#unordered

alien_0 = {'Color':'green','Points': 5}


#Accessing Value in Dictionary

alien_0_Color = alien_0['Color']
print(alien_0_Color)

#Adding New Key Value Pair
alien_0['Age'] = 21
alien_0 ['Time']= 'Current date and time'

print(alien_0)

retriveValue = alien_0['Time']
print(retriveValue)

#Modefying the Dictionary
alien_0 ={'X_position':0 ,'Y_position': 26 }
print(alien_0)

alien_0 ["Speed"] ="Slow"


print("alien's Y position is"+ str(alien_0['Y_position']))

if alien_0['Speed'] == 'Medium':
     x_increment = 1
 
elif alien_0['Speed'] == 'Slow':
    x_increment = 2

else:
    x_increment = 3
# This must be a fast alien.

alien_0['X_position']  = alien_0['X_position'] + x_increment
print("The new X position is "   + str(alien_0['X_position']))

alien_0 = {'color': 'green', 'points': 5}
del alien_0['color']
print(alien_0)

favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}

print("sarah's favourite language is " + favorite_languages["sarah"].title()+'.')


friends =['phil','sarah']
for names in favorite_languages.keys():
    print(names.title())
    if names in friends:
        print('Hi '+ names + ' i see your favourite language is '+favorite_languages[names].title())
    
if 'erin' not in favorite_languages.keys():
    print('Erin please roll it out!')
    
for name in sorted(favorite_languages.keys()):
    print(name.title()+"tanks for taking part in poll.")
    
print("List of languages: ")
for lang in sorted(favorite_languages.values()):
    print(lang.title())
for x in set(favorite_languages.values()):
     print(x.title())
    

alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

aliens = [alien_0,alien_1,alien_2]

for alien in aliens:
    print(alien)

alliens = []

for random in range(30):
    newAlliens = {'color': 'blue', 'points': 10}
    alliens.append(newAlliens)

for alien in alliens [:5]:
    print(alien)

#show how many can be created by this list

print ("total length in of aliens is"+str(len(alliens)))


for
# Out:
# green
# {'Color': 'green', 'Points': 5, 'Age': 21, 'Time': 'Current date and time'}
# Current date and time
# {'X_position': 0, 'Y_position': 26}
# alien's Y position is26
# The new X position is 2
# {'points': 5}
# sarah's favourite language is C.
# Jen
# Sarah
# Hi sarah i see your favourite language is C
# Edward
# Phil
# Hi phil i see your favourite language is Python
# Erin please roll it out!
# Edwardtanks for taking part in poll.
# Jentanks for taking part in poll.
# Philtanks for taking part in poll.
# Sarahtanks for taking part in poll.
# List of languages:
# C
# Python
# Python
# Ruby
# Ruby
# Python
# C
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}
# {'color': 'blue', 'points': 10}
# {'color': 'blue', 'points': 10}
# {'color': 'blue', 'points': 10}
# {'color': 'blue', 'points': 10}
# {'color': 'blue', 'points': 10}
# total length in of aliens is30
